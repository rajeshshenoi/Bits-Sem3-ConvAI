# %%
#!pip install ollama
! ollama list
# Out:
# NAME               ID              SIZE      MODIFIED
# llama3.2:latest    a80c4f17acd5    2.0 GB    47 seconds ago

# %%
from ollama import chat

response = chat(
  model='llama3.2',
  messages=[{'role': 'user', 'content': 'How many letter r are in strawberry?'}],
  think=True,
  stream=False,
)

print('Thinking:\n', response.message.thinking)
print('Answer:\n', response.message.content)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[23], line 3
#       1 from ollama import chat
#       2
# ----> 3 response = chat(
#       4   model='llama3.2',
#       5   messages=[{'role': 'user', 'content': 'How many letter r are in strawberry?'}],
#       6   think=True,
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:387, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     340 def chat(
#     341   self,
#     342   model: str = '',
#    (...)    352   keep_alive: Optional[Union[float, str]] = None,
#     353 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     354   """
#     355   Create a chat response using the requested model.
#     356
#    (...)    385   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     386   """
# --> 387   return self._request(
#     388     ChatResponse,
#     389     'POST',
#     390     '/api/chat',
#     391     json=ChatRequest(
#     392       model=model,
#     393       messages=list(_copy_messages(messages)),
#     394       tools=list(_copy_tools(tools)),
#     395       stream=stream,
#     396       think=think,
#     397       logprobs=logprobs,
#     398       top_logprobs=top_logprobs,
#     399       format=format,
#     400       options=options,
#     401       keep_alive=keep_alive,
#     402     ).model_dump(exclude_none=True),
#     403     stream=stream,
#     404   )
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:199, in Client._request(self, cls, stream, *args, **kwargs)
#     195         yield cls(**part)
#     197   return inner()
# --> 199 return cls(**self._request_raw(*args, **kwargs).json())
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:143, in Client._request_raw(self, *args, **kwargs)
#     141   return r
#     142 except httpx.HTTPStatusError as e:
# --> 143   raise ResponseError(e.response.text, e.response.status_code) from None
#     144 except httpx.ConnectError:
#     145   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: "llama3.2" does not support thinking (status code: 400)

# %%
import ollama

while True:
    question = input("Ask something (or type 'exit' to quit): ")

    if question.lower() in ['exit', 'quit']:
        print("Goodbye! 👋")
        break

    response = ollama.generate(model='gemma3:1b', prompt=question)

    print("Answer:", response['response'])
